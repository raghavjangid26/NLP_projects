# %%
# !pip install spacy

# %%
# !python3 -m spacy download en_core_web_sm
# Out:
# ...
#                                               0.0/12.8 MB ? eta -:--:--
#                                               0.0/12.8 MB ? eta -:--:--
#                                              0.0/12.8 MB 217.9 kB/s eta 0:00:59
#                                              0.1/12.8 MB 290.5 kB/s eta 0:00:44
#                                              0.1/12.8 MB 544.7 kB/s eta 0:00:24
#                                              0.1/12.8 MB 544.7 kB/s eta 0:00:24
#                                              0.1/12.8 MB 544.7 kB/s eta 0:00:24
#                                              0.1/12.8 MB 544.7 kB/s eta 0:00:24
#                                              0.1/12.8 MB 544.7 kB/s eta 0:00:24
#                                              0.1/12.8 MB 544.7 kB/s eta 0:00:24
#                                              0.1/12.8 MB 544.7 kB/s eta 0:00:24
#                                              0.1/12.8 MB 544.7 kB/s eta 0:00:24
# ...

# %%
text = "All happy families are alike; each unhappy family has unique problems."

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp(text)
for token in doc:
    print(token, token.idx)
# Out:
# All 0
# happy 4
# families 10
# are 19
# alike 23
# ; 28
# each 30
# unhappy 35
# family 43
# has 50
# unique 54
# problems 61
# . 69

# %%
text = "I love ChatGPT."

# %%
doc = nlp(text)
for token in doc:
    print(token, token.idx)
# Out:
# I 0
# love 2
# ChatGPT 7
# . 14
